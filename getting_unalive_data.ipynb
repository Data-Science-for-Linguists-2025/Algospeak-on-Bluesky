# %% [markdown]
# # Getting Unalive Data
# This notebook will get my second round of data utilizing the code from the [getting_bsky_data](https://github.com/Data-Science-for-Linguists-2025/Algospeak-on-Bluesky/blob/main/getting_bsky_data.ipynb) notebook.
#
# **Contents**
# - [1 Logging into the API](#1-Logging-into-the-API)
# - [2 Getting connected posts and other metadata](#2-Getting-connected-posts-and-other-metadata)
#     - [2.1 Converting URIs to URLs](#2.1-Converting-URIs-to-URLs)
# - [3 Getting Posts](#3-Getting-Posts)
#
# ## 1 Logging into the API

# %%
from atproto import Client, client_utils
import pandas as pd

fname = r'private\pw.txt'
file = open(fname, 'r')
pw = file.read()
file.close()

client = Client()
client.login('sararosenauling.bsky.social', pw)
# Out:
# ProfileViewDetailed(did='did:plc:66lizgbz577cdzpwnfyox3g6', handle='sararosenauling.bsky.social', associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:66lizgbz577cdzpwnfyox3g6/bafkreicddmiczeju5vfi5yxgp2oosshkakweumupixgkofwwkq6jp3nqiq@jpeg', banner='https://cdn.bsky.app/img/banner/plain/did:plc:66lizgbz577cdzpwnfyox3g6/bafkreih3qtqbp27r3sq6jskcn4wmb7oxmbbbt6p3lcmhd5zbqi6ww5k5pm@jpeg', created_at='2023-06-25T12:38:14.621Z', description='she/her - Sociolinguist studying the internet at Pitt! Also into kpop/kdrama, musicals, the Phillies, cross stiching and crocheting, and singing in general\n', display_name='Sara Rosenau', followers_count=948, follows_count=1071, indexed_at='2024-11-11T20:50:23.741Z', joined_via_starter_pack=None, labels=[], pinned_post=None, posts_count=325, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=KnownFollowers(count=479, followers=[ProfileViewBasic(did='did:plc:2pm74cxvyl4cjudcgieqx2bt', handle='anids.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:2pm74cxvyl4cjudcgieqx2bt/bafkreifeoqveli2zkeghzhvvb74sr5rxdcmaz3l42ezlqxsnhsm5cy7siu@jpeg', created_at='2023-06-11T05:32:49.606Z', display_name='Aniello De Santo', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:2pm74cxvyl4cjudcgieqx2bt/app.bsky.graph.follow/3jzpkswb74d27', following='at://did:plc:66lizgbz577cdzpwnfyox3g6/app.bsky.graph.follow/3jzpnae2d2x2v', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:rzybmhqhpkojcht6p3is4otu', handle='perayson.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:rzybmhqhpkojcht6p3is4otu/bafkreiab4evcpumkb4f7xk75hvcx24gpzdw2lbn3as45ct2necy4varzvm@jpeg', created_at='2023-07-24T12:06:19.171Z', display_name='Paul Rayson', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:rzybmhqhpkojcht6p3is4otu/app.bsky.graph.follow/3lawysmseg62a', following='at://did:plc:66lizgbz577cdzpwnfyox3g6/app.bsky.graph.follow/3lax5ca2q3y2r', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:ehcvp5dxsqsv6iwvkyzwcmox', handle='jasmijn.uk', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ehcvp5dxsqsv6iwvkyzwcmox/bafkreib5ukbvaplaqk72zse45quys6j44airiue4dygs7anw3ibfx3ujcm@jpeg', created_at='2024-02-02T10:36:59.496Z', display_name='Jasmijn Bastings', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:ehcvp5dxsqsv6iwvkyzwcmox/app.bsky.graph.follow/3lflagmqe7l2x', following='at://did:plc:66lizgbz577cdzpwnfyox3g6/app.bsky.graph.follow/3lflbex6hnj2p', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:g3edfc2p3go3x ...

# %% [markdown]
# ## 2 Getting connected posts and other metadata

# %%
results = client.app.bsky.feed.search_posts({'q': 'unalive', 'limit': 30, 'sort': 'top'})
results_dict = results.model_dump()

# %%
results_dict['posts'][2]
# Out:
# {'author': {'did': 'did:plc:uzfyjf4spsvvsn4mcqwxq4hs',
#   'handle': 'willraisesfunds.bsky.social',
#   'associated': {'chat': {'allow_incoming': 'following',
#     'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#    'feedgens': None,
#    'labeler': None,
#    'lists': None,
#    'starter_packs': None,
#    'py_type': 'app.bsky.actor.defs#profileAssociated'},
#   'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:uzfyjf4spsvvsn4mcqwxq4hs/bafkreigwi2logmvwjcmx6qvjlt6a5psxko7a3ldykq5n44oezsx7sxykti@jpeg',
#   'created_at': '2023-05-17T01:07:26.183Z',
#   'display_name': 'will',
#   'labels': [],
#   'viewer': {'blocked_by': False,
#    'blocking': None,
#    'blocking_by_list': None,
#    'followed_by': None,
#    'following': None,
#    'known_followers': None,
#    'muted': False,
#    'muted_by_list': None,
#    'py_type': 'app.bsky.actor.defs#viewerState'},
#   'py_type': 'app.bsky.actor.defs#profileViewBasic'},
#  'cid': 'bafyreicyncb7lqt7a55vcnmbztzrumf6cui3kg6a3rlh7fzd5lmvfzacgq',
#  'indexed_at': '2025-04-27T22:57:35.447Z',
#  'record': {'created_at': '2025-04-27T22:57:35.149Z',
#   'text': 'as much as I hate “unalive” (which is a lot) the use of “spicy” to describe anything romantic/sexual drives me even more crazy',
#   'embed': None,
#   'entities': None,
#   'facets': None,
#   'labels': None,
#   'langs': ['en'],
#   'reply': None,
#   'tags': None,
#   'py_type': 'app.bsky.feed.post'},
#  'uri': 'at://did:plc:uzfyjf4spsvvsn4mcqwxq4hs/app.bsky.feed.post/3lntdz6eqyc2o',
#  'embed': None,
#  'labels': [],
#  'like_count': 65,
#  'quote_count': 2,
#  'reply_count': 6,
#  'repost_count': 2,
#  'threadgate': None,
#  'viewer': {'embedding_disabled': False,
#   'like': None,
#   'pinned': None,
#   'reply_disabled': None,
#   'repost': None,
#   'thread_muted': False,
#   'py_type': 'app.bsky.feed.defs#viewerState'},
#  'py_type': 'app.bsky.feed.defs#postView'}

# %% [markdown]
# If a post is a reply to something, 'reply' under the 'record' is not None.
#
# ### 2.1 Converting URIs to URLs
#
# As explained in [this post](https://github.com/bluesky-social/atproto/discussions/2523)

# %%
import re
u = re.split('/', 'at://did:plc:awzzrtrcrvpnxi3ph2sbhxwv/app.bsky.feed.post/3lmt2lhdlwk2l')
u
# Out:
# ['at:',
#  '',
#  'did:plc:awzzrtrcrvpnxi3ph2sbhxwv',
#  'app.bsky.feed.post',
#  '3lmt2lhdlwk2l']

# %%
'https://bsky.app/profile/'+u[2]+'/post/'+u[4]
# Out:
# 'https://bsky.app/profile/did:plc:awzzrtrcrvpnxi3ph2sbhxwv/post/3lmt2lhdlwk2l'

# %%
def uri_to_url(uri):
    u = re.split('/', uri)
    url = 'https://bsky.app/profile/'+u[2]+'/post/'+u[4]
    return url

# %%
uri_to_url('at://did:plc:g7cu7736qmemcopvjip74g3b/app.bsky.feed.post/3lmt2wyd5q22a')
# Out:
# 'https://bsky.app/profile/did:plc:g7cu7736qmemcopvjip74g3b/post/3lmt2wyd5q22a'

# %% [markdown]
# ## 3 Getting Posts
# I can only get 100 posts at a time unfortunately...
# I'll just run it again on a different time frame

# %%
def search2df_top(query, since, until):
    results = client.app.bsky.feed.search_posts({'q': query, 'limit': 100, 'sort': 'top', 'since': since, 'until': until})
    results_dict = results.model_dump()
    query_data = []
    for post in results_dict['posts']:
        metadata = {}
        metadata['text'] = post['record']['text']
        metadata['author'] = post['author']['handle']
        metadata['display_name'] = post['author']['display_name']
        metadata['date'] = post['record']['created_at']
        metadata['likes'] = post['like_count']
        metadata['quotes'] = post['quote_count']
        metadata['replies'] = post['reply_count']
        metadata['reposts'] = post['repost_count']
        metadata['uri'] = post['uri']
        metadata['url'] = uri_to_url(post['uri'])

        if post['record']['reply'] is not None:
            metadata['reply_to'] = 'Yes'
            metadata['reply_to_uri'] = post['record']['reply']['parent']['uri']
            metadata['reply_to_url'] = uri_to_url(post['record']['reply']['parent']['uri'])
        else:
            metadata['reply_to'] = 'No'
            metadata['reply_to_uri'] = None
            metadata['reply_to_url'] = None
            
        metadata['query'] = query
        query_data.append(metadata)
    query_df = pd.DataFrame(query_data)
    return query_df

# %%
df = search2df_top('unalive', None, None)

# %%
pd.set_option('display.max_columns', 100) # not working for some reason :/
df.head()
# Out:
#                                                 text  \
# 0  Just saw a tiktok that said Luigi could be fac...
# 1                          Plan to unalive a cheeto.
# 2  as much as I hate “unalive” (which is a lot) t...
# 3  Alasdair Gold ran the London marathon whilst i...
# 4     🤬donald has shut down the unalive hotline \...
#
#                         author               display_name  \
# 0     bransonreese.bsky.social              Branson Reese
# 1         tsambuca.bsky.social               Tsambuca 🇨🇦🍁
# 2  willraisesfunds.bsky.social                       will
# 3        mickeygif.bsky.social  Mickey 'Club Signing' Gif
# 4   joleneandgrant.bsky.social   JOLENEandGRANT #elbowsup
#
#                        date  likes  quotes  replies  reposts  \
# 0  2025-04-27T18:07:39.513Z    223       1        9        7
# 1  2025-04-27T07:06:13.357Z     25       0        1        0
# 2  2025-04-27T22:57:35.149Z     65       2        6        2
# 3  2025-04-29T07:45:35.503Z     21       0        1        0
# 4  2025-04-28T04:14:31.913Z     18       1        2       12
#
#                                                  uri  \
# 0  at://did:plc:zat42a5ynbahtktax56auasx/app.bsky...
# 1  at://did:plc:kecwogf3ul6mt5yf4hm4upw4/app.bsky...
# 2  at://did:plc:uzfyjf4spsvvsn4mcqwxq4hs/app.bsky...
# 3  at://did:plc:qibxoac5ahyhhcka6fu7t3bl/app.bsky...
# 4  at://did:plc:6ulypwexav6e5ftfxdibwv77/app.bsky...
#
#                                                  url reply_to  \
# 0  https://bsky.app/profile/did:plc:zat42a5ynbaht...       No
# 1  https://bsky.app/profile/did:plc:kecwogf3ul6mt...      Yes
# 2  https://bsky.app/profile/did:plc:uzfyjf4spsvvs...       No
# 3  https://bsky.app/profile/did:plc:qibxoac5ahyhh...       No
# 4  https://bsky.app/profile/did:plc:6ulypwexav6e5...      Yes
#
#                                         reply_to_uri  \
# 0                                               None
# 1  at://did:plc:uqfjrpikgbri6xxcygyyugju/app.bsky...
# 2                                               None
# 3                                               None
# 4  at://did:plc:7qqkq2zdwq4j5jingukgtuky/app.bsky...
#
#                                         reply_to_url    query
# 0                                               None  unalive
# 1  https://bsky.app/profile/did:plc:uqfjrpikgbri6...  unalive
# 2                                               None  unalive
# 3                                               None  unalive
# 4  https://bsky.app/profile/did:plc:7qqkq2zdwq4j5...  unalive

# %%
df[['reply_to', 'reply_to_url']][:10] # seems to work!
# Out:
#   reply_to                                       reply_to_url
# 0       No                                               None
# 1      Yes  https://bsky.app/profile/did:plc:uqfjrpikgbri6...
# 2       No                                               None
# 3       No                                               None
# 4      Yes  https://bsky.app/profile/did:plc:7qqkq2zdwq4j5...
# 5      Yes  https://bsky.app/profile/did:plc:qxwx3yb4m3dmj...
# 6       No                                               None
# 7       No                                               None
# 8      Yes  https://bsky.app/profile/did:plc:rcchhh6t2do26...
# 9       No                                               None

# %%
# finding the timeframe of this set
date = df[['date']]
date
# Out:
#                         date
# 0   2025-04-27T18:07:39.513Z
# 1   2025-04-27T07:06:13.357Z
# 2   2025-04-27T22:57:35.149Z
# 3   2025-04-29T07:45:35.503Z
# 4   2025-04-28T04:14:31.913Z
# ..                       ...
# 95  2025-04-17T03:16:39.000Z
# 96  2025-04-16T18:24:14.009Z
# 97  2025-04-17T16:44:40.908Z
# 98  2025-04-15T02:50:06.393Z
# 99  2025-04-17T16:29:50.567Z
#
# [100 rows x 1 columns]

# %%
date.sort_values(by=['date'])
# Out:
#                         date
# 98  2025-04-15T02:50:06.393Z
# 96  2025-04-16T18:24:14.009Z
# 95  2025-04-17T03:16:39.000Z
# 88  2025-04-17T04:32:30.687Z
# 93  2025-04-17T14:49:07.836Z
# ..                       ...
# 22  2025-04-28T07:18:56.421Z
# 16  2025-04-28T23:38:58.264Z
# 45  2025-04-29T05:57:00.238Z
# 3   2025-04-29T07:45:35.503Z
# 6   2025-04-29T22:10:26.396Z
#
# [100 rows x 1 columns]

# %%
df2 = search2df_top('unalive', None ,'2025-03-31T00:00:00.000Z')
df2.head()
# Out:
#                                                 text  \
# 0               new "unalive" euphemism just dropped
# 1  Molly has every right to unalive Kristina by now.
# 2              can we extend this to "unalive" also?
# 3  Because in Dictatorships it’s a waste of money...
# 4  Every cold season, i have a deep fear of never...
#
#                      author           display_name                      date  \
# 0  joadsprocket.bsky.social  Joad The Wet Sprocket  2025-03-30T23:50:12.319Z
# 1     leslieb68.bsky.social                Leslie   2025-03-30T15:48:54.259Z
# 2       yodoops.bsky.social                 doops.  2025-03-30T16:29:52.359Z
# 3  debsmith1647.bsky.social                         2025-03-30T03:14:18.635Z
# 4   potat0princess.has.army             ✨ potato ✨  2025-03-30T16:37:32.374Z
#
#    likes  quotes  replies  reposts  \
# 0     28       0        0        0
# 1      3       0        1        0
# 2      4       0        1        0
# 3     29       0        1        1
# 4      2       0        1        0
#
#                                                  uri  \
# 0  at://did:plc:3nqgwlbyx4i6j553jilcb2lo/app.bsky...
# 1  at://did:plc:tnip6m3flxs2mrlt5bqlc5kd/app.bsky...
# 2  at://did:plc:heyj4lbfp3znjle5kjoxa3xv/app.bsky...
# 3  at://did:plc:stjjhxmg7igobpbyyiy6kt65/app.bsky...
# 4  at://did:plc:xygwtbnfmwfztjxs3ylvik4w/app.bsky...
#
#                                                  url reply_to  \
# 0  https://bsky.app/profile/did:plc:3nqgwlbyx4i6j...       No
# 1  https://bsky.app/profile/did:plc:tnip6m3flxs2m...      Yes
# 2  https://bsky.app/profile/did:plc:heyj4lbfp3znj...      Yes
# 3  https://bsky.app/profile/did:plc:stjjhxmg7igob...      Yes
# 4  https://bsky.app/profile/did:plc:xygwtbnfmwfzt...      Yes
#
#                                         reply_to_uri  \
# 0                                               None
# 1  at://did:plc:itooo5oj5hr255oyvszbboh7/app.bsky...
# 2  at://did:plc:h3y3f4pmwha4pqzekjpbjg4s/app.bsky...
# 3  at://did:plc:y5xyloyy7s4a2bwfeimj7r3b/app.bsky...
# 4  at://did:plc:xygwtbnfmwfztjxs3ylvik4w/app.bsky...
#
#                                         reply_to_url    query
# 0                                               None  unalive
# 1  https://bsky.app/profile/did:plc:itooo5oj5hr25...  unalive
# 2  https://bsky.app/profile/did:plc:h3y3f4pmwha4p...  unalive
# 3  https://bsky.app/profile/did:plc:y5xyloyy7s4a2...  unalive
# 4  https://bsky.app/profile/did:plc:xygwtbnfmwfzt...  unalive

# %%
date2 = df2[['date']]
date2.sort_values(by=['date']) # discrete time sequences!
# Out:
#                         date
# 98  2025-03-16T15:28:42.737Z
# 99  2025-03-16T16:44:12.457Z
# 97  2025-03-17T01:17:05.026Z
# 92  2025-03-17T05:22:54.143Z
# 83  2025-03-17T09:27:02.579Z
# ..                       ...
# 8   2025-03-30T13:50:11.523Z
# 1   2025-03-30T15:48:54.259Z
# 2   2025-03-30T16:29:52.359Z
# 4   2025-03-30T16:37:32.374Z
# 0   2025-03-30T23:50:12.319Z
#
# [100 rows x 1 columns]

# %%
unalive_top_df = pd.concat([df, df2])

# %%
unalive_top_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          200 non-null    object
#  1   author        200 non-null    object
#  2   display_name  200 non-null    object
#  3   date          200 non-null    object
#  4   likes         200 non-null    int64
#  5   quotes        200 non-null    int64
#  6   replies       200 non-null    int64
#  7   reposts       200 non-null    int64
#  8   uri           200 non-null    object
#  9   url           200 non-null    object
#  10  reply_to      200 non-null    object
#  11  reply_to_uri  92 non-null     object
#  12  reply_to_url  92 non-null     object
#  13  query         200 non-null    object
# dtypes: int64(4), object(10)
# memory usage: 23.4+ KB

# %%
unalive_top_df.tail()
# Out:
#                                                  text  \
# 95  Biodome2 failed. Looks like we should be tryin...
# 96  THEY'RE UNALIVING HER...\n\nTHEN THEY'RE GONNA...
# 97  If Labour cuts £675 a month ,I'll save the the...
# 98  PSA: starting tonight I'll be on a two-week so...
# 99  i think only trans people should be allowed to...
#
#                           author                       display_name  \
# 95    dawnwilliamson.bsky.social
# 96        beanycatte.bsky.social       I THINK THE DEATH PLAN SUCKS
# 97         emmadm101.bsky.social                     🇺🇦emmadm101 🇵🇸
# 98         amiberger.bsky.social                         Ami Berger
# 99  livinginjeopardy.bsky.social  transsexual anarchy cringe CEO 🔆🥦
#
#                         date  likes  quotes  replies  reposts  \
# 95  2025-03-17T10:29:55.416Z      6       0        0        0
# 96  2025-03-17T09:37:11.508Z      6       0        2        1
# 97  2025-03-17T01:17:05.026Z     21       0        0        5
# 98  2025-03-16T15:28:42.737Z    153       0        9        0
# 99  2025-03-16T16:44:12.457Z      7       0        0        1
#
#                                                   uri  \
# 95  at://did:plc:7aqvrita4kqxrcjwgw45opip/app.bsky...
# 96  at://did:plc:3u7o6h2rx7elcbipmuwmvmrz/app.bsky...
# 97  at://did:plc:ihdaraxh2s4vwlmw2yign5au/app.bsky...
# 98  at://did:plc:fhuifhwlgpfh233on5jrmxrl/app.bsky...
# 99  at://did:plc:bucg2dsfr66ecm7kc3bmepwv/app.bsky...
#
#                                                   url reply_to  \
# 95  https://bsky.app/profile/did:plc:7aqvrita4kqxr...      Yes
# 96  https://bsky.app/profile/did:plc:3u7o6h2rx7elc...       No
# 97  https://bsky.app/profile/did:plc:ihdaraxh2s4vw...      Yes
# 98  https://bsky.app/profile/did:plc:fhuifhwlgpfh2...       No
# 99  https://bsky.app/profile/did:plc:bucg2dsfr66ec...       No
#
#                                          reply_to_uri  \
# 95  at://did:plc:ux34natbhxube3xgdu3rhf45/app.bsky...
# 96                                               None
# 97  at://did:plc:vovinwhtulbsx4mwfw26r5ni/app.bsky...
# 98                                               None
# 99                                               None
#
#                                          reply_to_url    query
# 95  https://bsky.app/profile/did:plc:ux34natbhxube...  unalive
# 96                                               None  unalive
# 97  https://bsky.app/profile/did:plc:vovinwhtulbsx...  unalive
# 98                                               None  unalive
# 99                                               None  unalive

# %%
#unalive_top_df.to_csv('unalive_top_posts.csv', index=False)
